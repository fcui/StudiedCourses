# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
auto = pd.read_csv('../../data/Auto.csv', na_values=['?'])
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.shape
# Out:
# (397, 9)

# %%
np.array(auto.horsepower)
# Out:
# array([ 130.,  165.,  150.,  150.,  140.,  198.,  220.,  215.,  225.,
#         190.,  170.,  160.,  150.,  225.,   95.,   95.,   97.,   85.,
#          88.,   46.,   87.,   90.,   95.,  113.,   90.,  215.,  200.,
#         210.,  193.,   88.,   90.,   95.,   nan,  100.,  105.,  100.,
#          88.,  100.,  165.,  175.,  153.,  150.,  180.,  170.,  175.,
#         110.,   72.,  100.,   88.,   86.,   90.,   70.,   76.,   65.,
#          69.,   60.,   70.,   95.,   80.,   54.,   90.,   86.,  165.,
#         175.,  150.,  153.,  150.,  208.,  155.,  160.,  190.,   97.,
#         150.,  130.,  140.,  150.,  112.,   76.,   87.,   69.,   86.,
#          92.,   97.,   80.,   88.,  175.,  150.,  145.,  137.,  150.,
#         198.,  150.,  158.,  150.,  215.,  225.,  175.,  105.,  100.,
#         100.,   88.,   95.,   46.,  150.,  167.,  170.,  180.,  100.,
#          88.,   72.,   94.,   90.,   85.,  107.,   90.,  145.,  230.,
# ...

# %%
# auto.loc[auto['horsepower'] == '?', 'horsepower'] = np.nan
# auto.horsepower.replace('?', np.nan, inplace=True)

# %%
auto.dropna(inplace=True)

# %%
auto.reset_index(inplace=True)
auto
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0        0  18.0          8         307.0       130.0    3504          12.0
# 1        1  15.0          8         350.0       165.0    3693          11.5
# 2        2  18.0          8         318.0       150.0    3436          11.0
# 3        3  16.0          8         304.0       150.0    3433          12.0
# 4        4  17.0          8         302.0       140.0    3449          10.5
# 5        5  15.0          8         429.0       198.0    4341          10.0
# 6        6  14.0          8         454.0       220.0    4354           9.0
# 7        7  14.0          8         440.0       215.0    4312           8.5
# 8        8  14.0          8         455.0       225.0    4425          10.0
# 9        9  15.0          8         390.0       190.0    3850           8.5
# 10      10  15.0          8         383.0       170.0    3563          10.0
# ...

# %%
auto.horsepower = auto.horsepower.astype('float64')

# %% [markdown]
# ### (a)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
# index           392 non-null int64
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null float64
# horsepower      392 non-null float64
# weight          392 non-null int64
# acceleration    392 non-null float64
# year            392 non-null int64
# origin          392 non-null int64
# name            392 non-null object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 30.7+ KB

# %% [markdown]
# ### (b)

# %%
auto[['mpg', 'displacement', 'horsepower', 'acceleration',
      'weight']].agg([min, max])
# Out:
#       mpg  displacement  horsepower  acceleration  weight
# min   9.0          68.0        46.0           8.0    1613
# max  46.6         455.0       230.0          24.8    5140

# %% [markdown]
# ### (c)

# %%
auto[['mpg', 'displacement', 'horsepower', 'acceleration',
      'weight']].agg(['mean', 'std'])
# Out:
#             mpg  displacement  horsepower  acceleration       weight
# mean  23.445918    194.411990  104.469388     15.541327  2977.584184
# std    7.805007    104.644004   38.491160      2.758864   849.402560

# %% [markdown]
# ### (d)

# %%
newauto = auto.drop(np.arange(9, 85), axis=0)

# %%
newauto.reset_index(inplace=True)
newauto
# Out:
#      level_0  index   mpg  cylinders  displacement  horsepower  weight  \
# 0          0      0  18.0          8         307.0       130.0    3504
# 1          1      1  15.0          8         350.0       165.0    3693
# 2          2      2  18.0          8         318.0       150.0    3436
# 3          3      3  16.0          8         304.0       150.0    3433
# 4          4      4  17.0          8         302.0       140.0    3449
# 5          5      5  15.0          8         429.0       198.0    4341
# 6          6      6  14.0          8         454.0       220.0    4354
# 7          7      7  14.0          8         440.0       215.0    4312
# 8          8      8  14.0          8         455.0       225.0    4425
# 9         85     86  14.0          8         304.0       150.0    3672
# 10        86     87  13.0          8         350.0       145.0    3988
# 11        87     88  14.0          8         302.0       137.0    4042
# ...

# %%
newauto[['mpg', 'displacement', 'horsepower', 'acceleration',
         'weight']].agg([min, max])
# Out:
#       mpg  displacement  horsepower  acceleration  weight
# min  11.0          68.0        46.0           8.5    1649
# max  46.6         455.0       230.0          24.8    4997

# %%
newauto[['mpg', 'displacement', 'horsepower', 'acceleration',
         'weight']].agg(['mean', 'std'])
# Out:
#             mpg  displacement  horsepower  acceleration       weight
# mean  24.404430    187.240506  100.721519     15.726899  2935.971519
# std    7.867283     99.678367   35.708853      2.693721   811.300208

# %% [markdown]
# ### (e)

# %%
sns.pairplot(auto);
