# %%
X <- c(5, 5.5, 6, 6, 6, 6.5, 6.5, 6.5, 6.5, 7, 7, 8, 8, 9)

# %%
table(X) # table用来生成输入变量的相应频率
# Out:
# X
#   5 5.5   6 6.5   7   8   9
#   1   1   3   4   2   2   1

# %%
plot(table(X))
# Out:
# plot without title

# %% [markdown]
# # 问题

# %% [markdown]
# ## 1.2

# %%
customer <- c(4,2,1,1,0,2,1,2,4,2,5,3,1,5,1,5,1,2,1,1,3,4,2,4,3)
table(customer)
plot(table(customer))
# Out:
# customer
# 0 1 2 3 4 5
# 1 8 6 3 4 3
# plot without title
